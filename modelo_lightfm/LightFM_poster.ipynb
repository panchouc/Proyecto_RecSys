# %%
# !pip install sentence-transformers

# %%
# !pip install git+https://github.com/daviddavo/lightfm

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
import numpy as np
import pandas as pd
import random
from tqdm import tqdm

from scipy import sparse
from scipy.sparse import csr_matrix

from lightfm import LightFM
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import MultiLabelBinarizer

import warnings
warnings.filterwarnings("ignore")

np.random.seed(42)
random.seed(42)

# %%
header = "drive/MyDrive"

STEAM_META_PATH = os.path.join(header, "steam_store", "steam.csv")
STEAM_DESC_PATH = os.path.join(header, "steam_store", "steam_description_data.csv")
TRAIN_PATH = os.path.join(header, "data", "split", "train_split.csv")
VAL_PATH = os.path.join(header, "data", "split", "val_split.csv")
TEST_PATH = os.path.join(header, "data", "split", "test_split.csv")

# %% [markdown]
# La idea ahora es cargar todos los csvs.

# %%
def load_data():
    steam = pd.read_csv(STEAM_META_PATH)
    desc  = pd.read_csv(STEAM_DESC_PATH)
    train = pd.read_csv(TRAIN_PATH)
    val   = pd.read_csv(VAL_PATH)
    test  = pd.read_csv(TEST_PATH)

    # normalizar is_recommended
    def to_bool(x):
        if isinstance(x, str):
            return x.lower() == "true"
        return bool(x)

    for df in (train, val, test):
        if "is_recommended" not in df.columns:
            df["is_recommended"] = False
        df["is_recommended"] = df["is_recommended"].apply(to_bool)
        df["hours"] = df["hours"].clip(lower=0.0)

    return steam, desc, train, val, test


steam, desc, train, val, test = load_data()

# %% [markdown]
# Ahora mapeamos correctamente los usuarios e items para que Light pueda manejarlo sin problemas

# %%
def prepare_items(steam, desc, app_ids):
    steam["genres"] = steam["genres"].fillna("").apply(lambda x: x.split(";"))
    desc = desc.rename(columns={"steam_appid": "appid"})
    items = steam[steam.appid.isin(app_ids)].merge(desc, on="appid", how="left")
    items = items.drop_duplicates("appid").reset_index(drop=True)
    return items

all_app_ids = pd.concat([train.app_id, val.app_id, test.app_id]).unique()
items = prepare_items(steam, desc, all_app_ids)

def build_id_maps(train, val, test, items):
    users = np.sort(pd.concat([train.user_id, val.user_id, test.user_id]).unique())
    apps  = np.sort(items.appid.unique())
    user_id_map = {u: i for i, u in enumerate(users)}
    item_id_map = {a: i for i, a in enumerate(apps)}
    return user_id_map, item_id_map, users, apps

user_id_map, item_id_map, visible_users, visible_items = build_id_maps(train, val, test, items)

items_ordered = (
    items.set_index("appid")
         .loc[np.sort(list(item_id_map.keys()))]
         .reset_index()
)

# %% [markdown]
# Se usó sbert, basado en el práctico del curso y en la documentación
# encontrada en https://www.sbert.net/

# %%
def build_sbert_embeddings(items_ordered, batch_size=64, device="cuda"):
    model = SentenceTransformer("all-MiniLM-L6-v2", device=device)

    text = (
        items_ordered["short_description"].fillna("") + " " +
        items_ordered["about_the_game"].fillna("") + " " +
        items_ordered["detailed_description"].fillna("")
    ).tolist()

    emb = model.encode(
        text,
        batch_size=batch_size,
        convert_to_numpy=True,
        show_progress_bar=True,
        normalize_embeddings=True,
    )

    emb = sparse.csr_matrix(emb.astype(np.float32))
    print("SBERT embeddings:", emb.shape)
    return emb

item_text_emb = build_sbert_embeddings(items_ordered, device="cuda")
# Out:
# Batches:   0%|          | 0/30 [00:00<?, ?it/s]
# SBERT embeddings: (1872, 384)

# %% [markdown]
# Aquí usamos MultiLabelBinarizer, es algo que se encuentra en Scikit y nos basamos en https://www.kdnuggets.com/2023/01/encoding-categorical-features-multilabelbinarizer.html y en https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MultiLabelBinarizer.html

# %%
def split_tokens(series):
    return series.fillna("").apply(lambda x: [t.strip() for t in str(x).split(";") if t.strip()])

def build_categorical_features(items, top_cat=50):
    genres_mlb = MultiLabelBinarizer()
    genres = genres_mlb.fit_transform(split_tokens(items.genres))
    genres = sparse.csr_matrix(genres.astype(np.float32))

    cat_tokens = split_tokens(items.categories)
    all_cats = [c for lst in cat_tokens for c in lst]
    top = set(pd.Series(all_cats).value_counts().head(top_cat).index)

    cat_tokens_f = cat_tokens.apply(lambda lst: [c for c in lst if c in top])
    cats_mlb = MultiLabelBinarizer()
    categories = cats_mlb.fit_transform(cat_tokens_f)
    categories = sparse.csr_matrix(categories.astype(np.float32))

    return genres, categories

genres_mat, categories_mat = build_categorical_features(items_ordered)
item_features = sparse.hstack(
    [genres_mat, categories_mat, item_text_emb],
    format="csr",
    dtype=np.float32
)

# %% [markdown]
# Ya podemos generar las interacciones. Al igual que en el resto de modelos, consideramos que lo relevante es is_recommended = True

# %%
def build_interactions(df, user_id_map, item_id_map, mode="train"):

    df = df[df["app_id"].isin(item_id_map.keys())]

    if mode == "train":
        user_idx = df["user_id"].map(user_id_map)
        item_idx = df["app_id"].map(item_id_map)
        valid = user_idx.notnull() & item_idx.notnull()

        data = np.log1p(df.loc[valid, "hours"].values).astype(np.float32)
        return sparse.csr_matrix(
            (data, (user_idx[valid], item_idx[valid])),
            shape=(len(user_id_map), len(item_id_map)),
        )

    if mode == "eval":
        df2 = df.copy()
        mh = df2.groupby("user_id")["hours"].max()
        df2 = df2.merge(mh.rename("max_h"), left_on="user_id", right_index=True)

        user_idx = df2["user_id"].map(user_id_map)
        item_idx = df2["app_id"].map(item_id_map)
        valid = user_idx.notnull() & item_idx.notnull()

        data = np.ones(valid.sum(), dtype=np.float32)
        return sparse.csr_matrix(
            (data, (user_idx[valid], item_idx[valid])),
            shape=(len(user_id_map), len(item_id_map)),
        )

interactions_train = build_interactions(train, user_id_map, item_id_map, mode="train")
interactions_val   = build_interactions(val,   user_id_map, item_id_map, mode="eval")
interactions_test  = build_interactions(test,  user_id_map, item_id_map, mode="eval")

# %% [markdown]
# Generamos los features de usuario, para poder continuar.

# %%
def build_user_features(interactions, genres, categories):
    genres_bin = genres.astype(bool).astype(np.float32)
    cats_bin = categories.astype(bool).astype(np.float32)

    user_gen = interactions.dot(genres_bin)
    user_cat = interactions.dot(cats_bin)

    user_gen.data[:] = 1.0
    user_cat.data[:] = 1.0

    return sparse.hstack([user_gen, user_cat], format="csr", dtype=np.float32)

user_features = build_user_features(interactions_train, genres_mat, categories_mat)

# %% [markdown]
# Al igual que en los otros modelos, is_recommended True es lo relevante

# %%
def build_rel_idx_from_isrec(df, user_id_map, item_id_map):
    df2 = df[df["app_id"].isin(item_id_map.keys())].copy()
    df2["user_idx"] = df2["user_id"].map(user_id_map)
    df2["item_idx"] = df2["app_id"].map(item_id_map)

    all_users = df2["user_idx"].unique()

    df_rel = df2[df2["is_recommended"] == True]
    rel_true = df_rel.groupby("user_idx")["item_idx"].apply(set).to_dict()

    return {u: rel_true.get(u, set()) for u in all_users}

val_rel_idx  = build_rel_idx_from_isrec(val,  user_id_map, item_id_map)
test_rel_idx = build_rel_idx_from_isrec(test, user_id_map, item_id_map)

# %% [markdown]
# Ahora, definimos las métricas del mismo modo que en todo el proyecto.

# %%
def precision_at_k(rec_k, rel):
  return sum(i in rel for i in rec_k)/len(rec_k) if rec_k else 0

def recall_at_k(rec_k, rel):
  return sum(i in rel for i in rec_k)/len(rel) if rel else 0

def ndcg_at_k(rec_k, rel):
    if not rel: return 0.0
    dcg = sum(1/np.log2(r+2) for r,i in enumerate(rec_k) if i in rel)
    ideal = min(len(rel), len(rec_k))
    idcg = sum(1/np.log2(r+2) for r in range(ideal))
    return dcg/idcg if idcg > 0 else 0

def hit_at_k(rec_k, rel):
  return 1.0 if any(i in rel for i in rec_k) else 0

def map_at_k(rec_k, rel):
    if not rel: return 0
    hits, ap = 0, 0
    for r,it in enumerate(rec_k, start=1):
        if it in rel:
            hits += 1
            ap += hits/r
    return ap/len(rel)

def diversity_at_k(rec_dict, info_videojuegos):
    vals=[]
    for uid, recs in rec_dict.items():
        gs=set()
        for it in recs:
            if it in info_videojuegos:
                gs.update(info_videojuegos[it][1])
        vals.append(len(gs))
    return np.mean(vals)

# %% [markdown]
# También rescatamos info de los juegos, para calcular la diversidad

# %%
info_videojuegos = {
    item_id_map[row.appid]: (row.appid, row.genres)
    for _, row in items.iterrows()
    if isinstance(row.genres, list)
}

# %% [markdown]
# Además, filtramos items vistos, lo que es clave para lo visto.

# %%
train_seen = {
    u: set(interactions_train[u].indices)
    for u in range(interactions_train.shape[0])
}

# %% [markdown]
# Ahora definimos una función para evaluar el modelo. Opcionalmente, para hacer pruebas rápidas, usamos samples de usuarios, pero luego la idea es evaluar con todos.

# %%
def evaluate_lightfm(model, rel_idx, sample=None):

    n_users, n_items = interactions_train.shape

    users = list(rel_idx.keys())
    if sample:
        users = random.sample(users, min(sample, len(users)))

    rec_dict = {}
    P, R, N, H, M = [], [], [], [], []

    for u in users:

        item_ids = np.arange(n_items, dtype=np.int32)
        user_ids = np.repeat(u, n_items).astype(np.int32)

        scores = model.predict(
            user_ids,
            item_ids,
            item_features=item_features,
            user_features=user_features,
            num_threads=4
        )

        # filtrar vistos
        seen = train_seen.get(u, set())
        if seen:
            scores[list(seen)] = -1e9

        # top-10
        topk = np.argpartition(-scores, 10)[:10]
        topk = topk[np.argsort(-scores[topk])]
        topk = topk.tolist()

        rec_dict[u] = topk
        rel = rel_idx[u]

        P.append(precision_at_k(topk, rel))
        R.append(recall_at_k(topk, rel))
        N.append(ndcg_at_k(topk, rel))
        H.append(hit_at_k(topk, rel))
        M.append(map_at_k(topk, rel))

    diversity = diversity_at_k(rec_dict, info_videojuegos)

    out = {
        "P@10": np.mean(P),
        "R@10": np.mean(R),
        "F1@10": 2 * (np.mean(P) * np.mean(R)) / (np.mean(P) + np.mean(R)),
        "NDCG@10": np.mean(N),
        "HIT@10": np.mean(H),
        "MAP@10": np.mean(M),
        "Diversity@10": diversity,
    }

    print(out)
    return out

# %% [markdown]
# Finalmente, la idea es hacer un random search con 30 iteraciones sobre un conjunto amplio de hiperparámetros para buscar una combinación óptima.

# %% [markdown]
# Se usó warp y warp-koss como losses potenciales. Esta última optimiza directamente el ranking en el top-K, enfocando las actualizaciones en los errores que afectan los primeros puestos de la lista. Según Kula (2015), esta variante mejora recall y ndcg cuando hay señales implícitas y item features ricos (como SBERT), superando a BPR en escenarios con contenido semántico. Por lo tanto, usamos esas dos para probar.

# %%
param_space = {
    "loss": ["warp", "warp-kos"],
    "no_components": [32, 48, 64, 96],
    "learning_rate": [0.005, 0.01, 0.02],
    "epochs": [5, 8, 12],
    "item_alpha": [0.0, 1e-6, 1e-5],
    "user_alpha": [0.0, 1e-6, 1e-5],
}



def sample_params():
    return {
        "loss": random.choice(param_space["loss"]),
        "no_components": random.choice(param_space["no_components"]),
        "learning_rate": random.choice(param_space["learning_rate"]),
        "epochs": random.choice(param_space["epochs"]),
    }

best = None
results = []
print("empezamos")
for i in range(30):
    print(f"\n iter {i+1}/30")
    params = sample_params()
    print(params)

    model = LightFM(
        loss=params["loss"],
        no_components=params["no_components"],
        learning_rate=params["learning_rate"],
        random_state=42,
    )

    model.fit(
        interactions_train,
        item_features=item_features,
        user_features=user_features,
        epochs=params["epochs"],
        num_threads=4,
        verbose=False,
    )

    report = evaluate_lightfm(model, val_rel_idx, sample=800)
    score = report["R@10"]

    results.append({**params, **report})

    if best is None or score > best["R@10"]:
        best = {**params, **report, "model": model}
# Out:
# empezamos
#
#  iter 1/30
# {'loss': 'warp', 'no_components': 32, 'learning_rate': 0.02, 'epochs': 8}
# {'P@10': np.float64(0.005375000000000001), 'R@10': np.float64(0.04882440476190476), 'F1@10': np.float64(0.009683913568722202), 'NDCG@10': np.float64(0.027574043529210623), 'HIT@10': np.float64(0.05375), 'MAP@10': np.float64(0.020346230158730157), 'Diversity@10': np.float64(6.2225)}
#
#  iter 2/30
# {'loss': 'warp-kos', 'no_components': 64, 'learning_rate': 0.02, 'epochs': 5}
# {'P@10': np.float64(0.005), 'R@10': np.float64(0.047678571428571424), 'F1@10': np.float64(0.00905084745762712), 'NDCG@10': np.float64(0.02876451863719386), 'HIT@10': np.float64(0.05), 'MAP@10': np.float64(0.02293076814058957), 'Diversity@10': np.float64(5.555)}
#
#  iter 3/30
# {'loss': 'warp-kos', 'no_components': 64, 'learning_rate': 0.01, 'epochs': 5}
# {'P@10': np.float64(0.004125), 'R@10': np.float64(0.039375), 'F1@10': np.float64(0.007467672413793104), 'NDCG@10': np.float64(0.02049306890069856), 'HIT@10': np.float64(0.04125), 'MAP@10': np.float64(0.014588045634920634), 'Diversity@10': np.float64(6.23875)}
#
#  iter 4/30
# {'loss': 'warp-kos', 'no_components': 32, 'learning_rate': 0.02, 'epochs': 5}
# {'P@10': np.float64(0.0055000000000000005), 'R@10': np.float64(0.05052083333333333), 'F1@10': np.float64(0.009920044626255113), 'NDCG@10': np.float64(0.026231380290189944), 'HIT@10': np.float64(0.055), 'MAP@10': np.float64(0.01817485119047619), 'Diversity@10': np.float64(5.81)}
#
#  iter 5/30
# {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.005, 'epochs': 8}
# {'P@10': np.float64(0.006750000000000001), 'R@10': np.float64(0.06384615384615384), 'F1@10': np.float64(0.012209207300463088), 'NDCG@10': np.float64(0.03097392620044952), 'HIT@10': np.float64(0.0675), 'MAP@10': np.float64(0.020674088064713065), 'Diversity@10': np.float64(7.3575)}
#
#  iter 6/30
# {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.005, 'epochs': 12}
# {'P@10': np.float64(0.00625), 'R@10': np.float64(0.05790865384615385), 'F1@10': np.float64(0.011282315473960285), 'NDCG@10': np.float64(0.036291304039131), 'HIT@10': np.float64(0.0625), 'MAP@10': np.float64(0.029141597985347985), 'Diversity@10': np.float64(7.1975)}
#
#  iter 7/30
# {'loss': 'warp-kos', 'no_components': 48, 'learning_rate': 0.01, 'epochs': 5}
# {'P@10': np.float64(0.006999999999999999), 'R@10': np.float64(0.06551282051282051), 'F1@10': np.float64(0.012648514851485146), 'NDCG@10': np.float64(0.0316869592417482), 'HIT@10': np.float64(0.07), 'MAP@10': np.float64(0.02111378205128205), 'Diversity@10': np.float64(6.78375)}
#
#  iter 8/30
# {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.01, 'epochs': 12}
# {'P@10': np.float64(0.006625000000000001), 'R@10': np.float64(0.06125), 'F1@10': np.float64(0.011956721915285452), 'NDCG@10': np.float64(0.033880097579153674), 'HIT@10': np.float64(0.06625), 'MAP@10': np.float64(0.02490438988095238), 'Diversity@10': np.float64(6.11)}
#
#  iter 9/30
# {'loss': 'warp', 'no_components': 32, 'learning_rate': 0.01, 'epochs': 5}
# {'P@10': np.float64(0.0065000000000000014), 'R@10': np.float64(0.05916666666666666), 'F1@10': np.float64(0.011713197969543149), 'NDCG@10': np.float64(0.03044747867455474), 'HIT@10': np.float64(0.065), 'MAP@10': np.float64(0.02112458664021164), 'Diversity@10': np.float64(7.07375)}
#
#  iter 10/30
# {'loss': 'warp', 'no_components': 48, 'learning_rate': 0.02, 'epochs': 12}
# {'P@10': np.float64(0.005), 'R@10': np.float64(0.0459375), 'F1@10': np.float64(0.009018404907975461), 'NDCG@10': np.float64(0.02525661241308207), 'HIT@10': np.float64(0.0475), 'MAP@10': np.float64(0.018710565476190474), 'Diversity@10': np.float64(5.8425)}
#
#  iter 11/30
# {'loss': 'warp-kos', 'no_components': 64, 'learning_rate': 0.02, 'epochs': 5}
# {'P@10': np.float64(0.005875), 'R@10': np.float64(0.051500000000000004), 'F1@10': np.float64(0.010546840958605665), 'NDCG@10': np.float64(0.026817089048323018), 'HIT@10': np.float64(0.0575), 'MAP@10': np.float64(0.018682457010582007), 'Diversity@10': np.float64(5.255)}
#
#  iter 12/30
# {'loss': 'warp-kos', 'no_components': 64, 'learning_rate': 0.005, 'epochs': 5}
# {'P@10': np.float64(0.006999999999999999), 'R@10': np.float64(0.061045558608058596), 'F1@10': np.float64(0.012559788441675103), 'NDCG@10': np.float64(0.027445430647505396), 'HIT@10': np.float64(0.06875), 'MAP@10': np.float64(0.0168543777981278), 'Diversity@10': np.float64(7.19625)}
#
#  iter 13/30
# {'loss': 'warp-kos', 'no_components': 64, 'learning_rate': 0.02, 'epochs': 8}
# {'P@10': np.float64(0.00425), 'R@10': np.float64(0.038679487179487174), 'F1@10': np.float64(0.007658503807675078), 'NDCG@10': np.float64(0.0193951637952281), 'HIT@10': np.float64(0.0425), 'MAP@10': np.float64(0.013245169413919414), 'Diversity@10': np.float64(5.35125)}
#
#  iter 14/30
# {'loss': 'warp', 'no_components': 32, 'learning_rate': 0.005, 'epochs': 12}
# {'P@10': np.float64(0.0055000000000000005), 'R@10': np.float64(0.051875), 'F1@10': np.float64(0.009945533769063182), 'NDCG@10': np.float64(0.028209549319667234), 'HIT@10': np.float64(0.05375), 'MAP@10': np.float64(0.02070436507936508), 'Diversity@10': np.float64(7.6175)}
#
#  iter 15/30
# {'loss': 'warp-kos', 'no_components': 48, 'learning_rate': 0.02, 'epochs': 12}
# {'P@10': np.float64(0.0055000000000000005), 'R@10': np.float64(0.04895833333333333), 'F1@10': np.float64(0.009889058913542467), 'NDCG@10': np.float64(0.02666578632369883), 'HIT@10': np.float64(0.05375), 'MAP@10': np.float64(0.01936706349206349), 'Diversity@10': np.float64(5.58875)}
#
#  iter 16/30
# {'loss': 'warp-kos', 'no_components': 48, 'learning_rate': 0.02, 'epochs': 12}
# {'P@10': np.float64(0.00575), 'R@10': np.float64(0.051875), 'F1@10': np.float64(0.010352494577006509), 'NDCG@10': np.float64(0.02520257909015654), 'HIT@10': np.float64(0.05625), 'MAP@10': np.float64(0.016731894841269843), 'Diversity@10': np.float64(5.37625)}
#
#  iter 17/30
# {'loss': 'warp-kos', 'no_components': 96, 'learning_rate': 0.005, 'epochs': 8}
# {'P@10': np.float64(0.005125000000000001), 'R@10': np.float64(0.049166666666666664), 'F1@10': np.float64(0.009282425172678434), 'NDCG@10': np.float64(0.02539210788284421), 'HIT@10': np.float64(0.05125), 'MAP@10': np.float64(0.018041170634920632), 'Diversity@10': np.float64(6.7525)}
#
#  iter 18/30
# {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.01, 'epochs': 8}
# {'P@10': np.float64(0.006125), 'R@10': np.float64(0.05321130952380953), 'F1@10': np.float64(0.010985491799167378), 'NDCG@10': np.float64(0.025466097810753548), 'HIT@10': np.float64(0.06), 'MAP@10': np.float64(0.01626636904761905), 'Diversity@10': np.float64(6.31375)}
#
#  iter 19/30
# {'loss': 'warp-kos', 'no_components': 96, 'learning_rate': 0.01, 'epochs': 12}
# {'P@10': np.float64(0.005124999999999999), 'R@10': np.float64(0.04583333333333334), 'F1@10': np.float64(0.009219133278822567), 'NDCG@10': np.float64(0.022618134904182612), 'HIT@10': np.float64(0.05125), 'MAP@10': np.float64(0.014971726190476192), 'Diversity@10': np.float64(5.7925)}
#
#  iter 20/30
# {'loss': 'warp-kos', 'no_components': 48, 'learning_rate': 0.01, 'epochs': 12}
# {'P@10': np.float64(0.005), 'R@10': np.float64(0.04354166666666666), 'F1@10': np.float64(0.008969957081545065), 'NDCG@10': np.float64(0.020368145808798088), 'HIT@10': np.float64(0.04875), 'MAP@10': np.float64(0.012708498677248676), 'Diversity@10': np.float64(5.95375)}
#
#  iter 21/30
# {'loss': 'warp', 'no_components': 32, 'learning_rate': 0.02, 'epochs': 8}
# {'P@10': np.float64(0.006125), 'R@10': np.float64(0.0578125), 'F1@10': np.float64(0.011076490713587487), 'NDCG@10': np.float64(0.029864117052528366), 'HIT@10': np.float64(0.06125), 'MAP@10': np.float64(0.021099702380952382), 'Diversity@10': np.float64(5.98125)}
#
#  iter 22/30
# {'loss': 'warp-kos', 'no_components': 48, 'learning_rate': 0.005, 'epochs': 12}
# {'P@10': np.float64(0.005875), 'R@10': np.float64(0.05625), 'F1@10': np.float64(0.01063883299798793), 'NDCG@10': np.float64(0.031396674153131014), 'HIT@10': np.float64(0.05875), 'MAP@10': np.float64(0.023461309523809523), 'Diversity@10': np.float64(7.21875)}
#
#  iter 23/30
# {'loss': 'warp-kos', 'no_components': 96, 'learning_rate': 0.005, 'epochs': 12}
# {'P@10': np.float64(0.005124999999999999), 'R@10': np.float64(0.04791666666666666), 'F1@10': np.float64(0.009259622937941869), 'NDCG@10': np.float64(0.025190219199047972), 'HIT@10': np.float64(0.05125), 'MAP@10': np.float64(0.0176792328042328), 'Diversity@10': np.float64(6.5375)}
#
#  iter 24/30
# {'loss': 'warp-kos', 'no_components': 32, 'learning_rate': 0.02, 'epochs': 8}
# {'P@10': np.float64(0.00525), 'R@10': np.float64(0.04967857142857143), 'F1@10': np.float64(0.009496423927178154), 'NDCG@10': np.float64(0.022419212754424635), 'HIT@10': np.float64(0.0525), 'MAP@10': np.float64(0.014019295634920634), 'Diversity@10': np.float64(5.81625)}
#
#  iter 25/30
# {'loss': 'warp', 'no_components': 48, 'learning_rate': 0.01, 'epochs': 8}
# {'P@10': np.float64(0.0055000000000000005), 'R@10': np.float64(0.04958333333333333), 'F1@10': np.float64(0.009901664145234494), 'NDCG@10': np.float64(0.027748449653678117), 'HIT@10': np.float64(0.05375), 'MAP@10': np.float64(0.02035945767195767), 'Diversity@10': np.float64(6.445)}
#
#  iter 26/30
# {'loss': 'warp-kos', 'no_components': 48, 'learning_rate': 0.005, 'epochs': 5}
# {'P@10': np.float64(0.005875), 'R@10': np.float64(0.0543452380952381), 'F1@10': np.float64(0.010603686863694771), 'NDCG@10': np.float64(0.025584973410149578), 'HIT@10': np.float64(0.05875), 'MAP@10': np.float64(0.0163640873015873), 'Diversity@10': np.float64(7.81625)}
#
#  iter 27/30
# {'loss': 'warp', 'no_components': 48, 'learning_rate': 0.01, 'epochs': 12}
# {'P@10': np.float64(0.004875000000000001), 'R@10': np.float64(0.041636904761904764), 'F1@10': np.float64(0.008728084207832098), 'NDCG@10': np.float64(0.01943476572274327), 'HIT@10': np.float64(0.04875), 'MAP@10': np.float64(0.012107473544973546), 'Diversity@10': np.float64(6.4825)}
#
#  iter 28/30
# {'loss': 'warp', 'no_components': 64, 'learning_rate': 0.005, 'epochs': 5}
# {'P@10': np.float64(0.006000000000000001), 'R@10': np.float64(0.056666666666666664), 'F1@10': np.float64(0.010851063829787235), 'NDCG@10': np.float64(0.0266672518538965), 'HIT@10': np.float64(0.06), 'MAP@10': np.float64(0.01731175595238095), 'Diversity@10': np.float64(7.3925)}
#
#  iter 29/30
# {'loss': 'warp-kos', 'no_components': 32, 'learning_rate': 0.01, 'epochs': 5}
# {'P@10': np.float64(0.004875), 'R@10': np.float64(0.041845238095238095), 'F1@10': np.float64(0.008732641100777169), 'NDCG@10': np.float64(0.020509038237824163), 'HIT@10': np.float64(0.0475), 'MAP@10': np.float64(0.0133171768707483), 'Diversity@10': np.float64(6.75)}
#
#  iter 30/30
# {'loss': 'warp-kos', 'no_components': 48, 'learning_rate': 0.02, 'epochs': 12}
# {'P@10': np.float64(0.00525), 'R@10': np.float64(0.046375), 'F1@10': np.float64(0.00943220338983051), 'NDCG@10': np.float64(0.02335447900021954), 'HIT@10': np.float64(0.05125), 'MAP@10': np.float64(0.01581111111111111), 'Diversity@10': np.float64(5.47375)}

# %% [markdown]
# Con la mejor combinación, ya evaluamos en test

# %%
print("\nmejor config")
print(best)

print("\nev final en test")
test_report = evaluate_lightfm(best["model"], test_rel_idx, sample=None)
print(test_report)
# Out:
# mejor config
# {'loss': 'warp-kos', 'no_components': 48, 'learning_rate': 0.01, 'epochs': 5, 'P@10': np.float64(0.006999999999999999), 'R@10': np.float64(0.06551282051282051), 'F1@10': np.float64(0.012648514851485146), 'NDCG@10': np.float64(0.0316869592417482), 'HIT@10': np.float64(0.07), 'MAP@10': np.float64(0.02111378205128205), 'Diversity@10': np.float64(6.78375), 'model': <lightfm.lightfm.LightFM object at 0x7cf635fc3290>}
#
# ev final en test
# {'P@10': np.float64(0.004957231726283048), 'R@10': np.float64(0.044401328324345436), 'F1@10': np.float64(0.008918723448689938), 'NDCG@10': np.float64(0.022094348416813795), 'HIT@10': np.float64(0.048989113530326596), 'MAP@10': np.float64(0.014716576264010166), 'Diversity@10': np.float64(6.880637636080871)}
# {'P@10': np.float64(0.004957231726283048), 'R@10': np.float64(0.044401328324345436), 'F1@10': np.float64(0.008918723448689938), 'NDCG@10': np.float64(0.022094348416813795), 'HIT@10': np.float64(0.048989113530326596), 'MAP@10': np.float64(0.014716576264010166), 'Diversity@10': np.float64(6.880637636080871)}
